# %% [markdown]
# Hugging Face - Text to Speech

# %%
# !pip install ipykernel
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipykernel in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (6.29.5)
# Requirement already satisfied: nest-asyncio in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipykernel) (1.8.13)
# Requirement already satisfied: tornado>=6.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipykernel) (6.4.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: pyzmq>=24 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipykernel) (26.2.1)
# Requirement already satisfied: packaging in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipykernel) (24.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: psutil in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipykernel) (8.34.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (3.0.50)
# Requirement already satisfied: exceptiongroup in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (1.2.2)
# Requirement already satisfied: decorator in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: typing_extensions>=4.6 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.12.2)
# Requirement already satisfied: stack_data in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: pygments>=2.4.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (2.19.1)
# Requirement already satisfied: pexpect>4.3 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: ipywidgets in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (8.1.5)
# Requirement already satisfied: ipython>=6.1.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipywidgets) (8.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: exceptiongroup in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: typing_extensions>=4.6 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: decorator in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.50)
# Requirement already satisfied: stack_data in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: matplotlib-inline in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pygments>=2.4.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: pure-eval in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)

# %%
# Install the packages
# !pip install transformers
# !pip install timm
# !pip install timm
# !pip install inflect
# !pip install phonemizer
# !pip install accelerate
# !pip install scipy
# !pip install py-espeak-ng
# Out:
# Requirement already satisfied: transformers in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (4.49.0)
# Requirement already satisfied: numpy>=1.17 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from transformers) (2.2.3)
# Requirement already satisfied: requests in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from transformers) (0.29.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: packaging>=20.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: filelock in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from transformers) (3.17.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: timm in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (1.0.15)
# Requirement already satisfied: pyyaml in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from timm) (6.0.2)
# Requirement already satisfied: torchvision in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from timm) (0.21.0)
# Requirement already satisfied: torch in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from timm) (2.6.0)
# Requirement already satisfied: huggingface_hub in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from timm) (0.29.2)
# Requirement already satisfied: safetensors in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from timm) (0.5.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: filelock in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface_hub->timm) (3.17.0)
# Requirement already satisfied: packaging>=20.9 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface_hub->timm) (24.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface_hub->timm) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface_hub->timm) (2025.3.0)
# Requirement already satisfied: requests in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (3.2.0)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: jinja2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: networkx in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (3.4.2)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (11.6.1.9)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (10.3.5.147)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.3.1.170)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.4.5.8)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (9.1.0.70)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (11.2.1.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (2.21.5)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (0.6.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: numpy in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torchvision->timm) (2.2.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torchvision->timm) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from jinja2->torch->timm) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (2025.1.31)
# Requirement already satisfied: timm in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (1.0.15)
# Requirement already satisfied: safetensors in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from timm) (0.5.3)
# Requirement already satisfied: pyyaml in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from timm) (6.0.2)
# Requirement already satisfied: torch in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from timm) (2.6.0)
# Requirement already satisfied: huggingface_hub in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from timm) (0.29.2)
# Requirement already satisfied: torchvision in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from timm) (0.21.0)
# Requirement already satisfied: requests in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface_hub->timm) (2025.3.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface_hub->timm) (4.12.2)
# Requirement already satisfied: packaging>=20.9 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface_hub->timm) (24.2)
# Requirement already satisfied: filelock in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface_hub->timm) (3.17.0)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.3.1.170)
# Requirement already satisfied: networkx in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (3.4.2)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (9.1.0.70)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (0.6.2)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (10.3.5.147)
# Requirement already satisfied: sympy==1.13.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: jinja2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (11.2.1.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (2.21.5)
# Requirement already satisfied: triton==3.2.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (3.2.0)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch->timm) (11.6.1.9)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: numpy in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torchvision->timm) (2.2.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torchvision->timm) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from jinja2->torch->timm) (3.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (3.4.1)
# Requirement already satisfied: inflect in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (7.5.0)
# Requirement already satisfied: more_itertools>=8.5.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from inflect) (10.6.0)
# Requirement already satisfied: typeguard>=4.0.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from inflect) (4.4.2)
# Requirement already satisfied: typing_extensions>=4.10.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from typeguard>=4.0.1->inflect) (4.12.2)
# Requirement already satisfied: phonemizer in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (3.3.0)
# Requirement already satisfied: segments in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from phonemizer) (2.3.0)
# Requirement already satisfied: attrs>=18.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from phonemizer) (25.1.0)
# Requirement already satisfied: typing-extensions in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from phonemizer) (4.12.2)
# Requirement already satisfied: dlinfo in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from phonemizer) (2.0.0)
# Requirement already satisfied: joblib in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from phonemizer) (1.4.2)
# Requirement already satisfied: regex in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from segments->phonemizer) (2024.11.6)
# Requirement already satisfied: csvw>=1.5.6 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from segments->phonemizer) (3.5.1)
# Requirement already satisfied: rfc3986<2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from csvw>=1.5.6->segments->phonemizer) (1.5.0)
# Requirement already satisfied: uritemplate>=3.0.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from csvw>=1.5.6->segments->phonemizer) (4.1.1)
# Requirement already satisfied: python-dateutil in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from csvw>=1.5.6->segments->phonemizer) (2.9.0.post0)
# Requirement already satisfied: jsonschema in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from csvw>=1.5.6->segments->phonemizer) (4.23.0)
# Requirement already satisfied: isodate in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from csvw>=1.5.6->segments->phonemizer) (0.7.2)
# Requirement already satisfied: language-tags in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from csvw>=1.5.6->segments->phonemizer) (1.2.0)
# Requirement already satisfied: babel in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from csvw>=1.5.6->segments->phonemizer) (2.17.0)
# Requirement already satisfied: colorama in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from csvw>=1.5.6->segments->phonemizer) (0.4.6)
# Requirement already satisfied: requests in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from csvw>=1.5.6->segments->phonemizer) (2.32.3)
# Requirement already satisfied: rdflib in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from csvw>=1.5.6->segments->phonemizer) (7.1.3)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (0.23.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (0.36.2)
# Requirement already satisfied: six>=1.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from python-dateutil->csvw>=1.5.6->segments->phonemizer) (1.17.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from rdflib->csvw>=1.5.6->segments->phonemizer) (3.2.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->csvw>=1.5.6->segments->phonemizer) (2025.1.31)
# Requirement already satisfied: accelerate in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from accelerate) (0.29.2)
# Requirement already satisfied: psutil in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from accelerate) (24.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from accelerate) (2.2.3)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from accelerate) (0.5.3)
# Requirement already satisfied: pyyaml in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from accelerate) (2.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: filelock in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.17.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: jinja2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: networkx in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.1.31)
# Requirement already satisfied: scipy in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (1.15.2)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (from scipy) (2.2.3)
# Requirement already satisfied: py-espeak-ng in /opt/projects/hugging_face_demos/hf_text_to_speech/venv/lib/python3.10/site-packages (0.1.8)

# %%
from transformers import VitsModel, AutoTokenizer
import torch
import numpy as np
import scipy

# %%
model = VitsModel.from_pretrained("kakao-enterprise/vits-ljs")
tokenizer = AutoTokenizer.from_pretrained("kakao-enterprise/vits-ljs")

# %%
text = "Hey, it's Hugging Face Text to Speech running locally"
inputs = tokenizer(text, return_tensors="pt")

# %%
with torch.no_grad():
    output = model(**inputs).waveform

# %%
audio_array = output.cpu().numpy().squeeze()
audio_array /=1.414
audio_array *= 32767
audio_array = audio_array.astype(np.int16)
# print(audio_array)

# %%
scipy.io.wavfile.write("output/output.wav", rate=model.config.sampling_rate, data=audio_array)

# %%
from IPython.display import Audio as IPythonAudio

IPythonAudio(audio_array,
             rate=model.config.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
